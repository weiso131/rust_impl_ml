# %%
import random


def gernerate_data(a_num, b_num):


# 設定群的中心點
    cluster_1_center = [2, 2]
    cluster_2_center = [8, 8]


    cluster_1 = [[round(random.gauss(cluster_1_center[0], 1), 3),
                round(random.gauss(cluster_1_center[1], 1), 3)] for _ in range(a_num)]


    cluster_2 = [[round(random.gauss(cluster_2_center[0], 1), 3),
                round(random.gauss(cluster_2_center[1], 1), 3)] for _ in range(b_num)]

    # 合併兩個群的資料
    data = cluster_1 + cluster_2

    # 將資料展平為一維 list
    

    return data

data = gernerate_data(15, 15)
data_1d = [value for sublist in data for value in sublist]
print(data_1d)
# Out:
# [1.397, 2.419, 2.663, 2.426, 2.603, 2.485, 1.954, 1.25, 2.296, 2.91, 1.668, 2.932, 0.941, 1.06, 2.244, 2.397, 2.775, 2.583, 2.382, 1.884, 2.606, 2.208, 3.873, 1.883, 2.326, 3.278, 1.834, 3.416, 3.371, 1.859, 8.3, 9.373, 8.399, 9.382, 7.4, 7.382, 8.187, 8.249, 10.052, 7.334, 8.115, 8.998, 8.937, 10.071, 8.353, 8.884, 9.412, 7.148, 7.237, 7.93, 6.455, 8.736, 8.355, 7.858, 8.179, 8.945, 9.357, 7.207, 8.043, 7.861]

# %%
import matplotlib.pyplot as plt
# 將資料轉換為 x 和 y 的形式
x_values = [point[0] for point in data]
y_values = [point[1] for point in data]

# 繪製散點圖
plt.scatter(x_values, y_values, c='blue', label='Data Points')
plt.title('Scatter Plot of Random Data')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend()
plt.grid()
plt.show()

# %%
test_data = gernerate_data(5, 5)
test_data_1d = [value for sublist in test_data for value in sublist]
print(test_data_1d)
print(len(test_data_1d))
# Out:
# [2.133, 2.218, 1.047, 2.394, 3.8, 2.77, 2.312, 2.323, 1.261, -0.484, 6.175, 6.895, 8.231, 7.682, 8.504, 7.792, 6.739, 6.102, 6.659, 10.024]
# 20
